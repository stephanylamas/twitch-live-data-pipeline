# %% [markdown]
# ## Twitch Live Data Pipeline
#
# Project development tutorial and debugging reference.

# %% [markdown]
# 1. Created file hierarchy for pipeline, data and objects to be stored appropiately
# 2. Read through entire Twitch API Documentation
# 3. Read through entire EventSub Documentation
# 3. Created Twitch account
# 4. Log into Twitch Developer console https://dev.twitch.tv/
# 5. Create a Twitch application for the data pipeline
# 6. Decide on tech stack
